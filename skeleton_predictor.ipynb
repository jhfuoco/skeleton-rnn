# %%
import os
import json
import time
import csv
import cv2
import torch
import numpy as np
from pathlib import Path
import tensorflow as tf
import sys
sys.path.insert(0, '/Users/jihoon/venvs/yolov7-pose-tracking')
from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import check_imshow, increment_path, set_logging, check_img_size, non_max_suppression, scale_coords
from utils.plots import draw_boxes
from utils.torch_utils import select_device, time_synchronized, TracedModel
from pose.utils.datasets import LoadImages as PoseLoadImages
from pose.detect import detect
from sort import Sort

# %%
def model_load(weights, device, imgsz):
    model = attempt_load(weights, map_location=device)
    stride = int(model.stride.max())
    imgsz = check_img_size(imgsz, s=stride)
    return model, stride, imgsz


def view_image(p, im0):
    cv2.imshow(str(p), im0)
    if cv2.waitKey(1) == ord('q'):
        cv2.destroyAllWindows()


def img_prep(img, device, half):
    img = torch.from_numpy(img).to(device)
    img = img.half() if half else img.float()
    img /= 255.0
    if img.ndimension() == 3:
        img = img.unsqueeze(0)
    return img


def track(det, img, im0, sort_tracker):
    det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()
    dets_to_sort = np.empty((0, 6))
    for x1, y1, x2, y2, conf, detclass in det.cpu().detach().numpy():
        dets_to_sort = np.vstack((dets_to_sort, np.array([x1, y1, x2, y2, conf, detclass])))
    tracked_dets = sort_tracker.update(dets_to_sort)
    return tracked_dets


def predict_walk_type_with_confidence(model, skeleton_data):
    MAX_SEQUENCE_LENGTH = 632  # 학습 데이터의 최대 시퀀스 길이
    
    # Add this line to print the length and some values of skeleton_data
    # print("Length of skeleton_data:", len(skeleton_data))
    # print("First few values of skeleton_data:", skeleton_data[:10])
       
    # Convert the skeleton_data to a numpy array and reshape it to fit LSTM input shape
    skeleton_data = np.array(skeleton_data).reshape(1, 1, 34)
    
    # Adjust the padding to match training data length
    skeleton_data_padded = tf.keras.preprocessing.sequence.pad_sequences(skeleton_data, padding='post', dtype='float32', maxlen=MAX_SEQUENCE_LENGTH)
    skeleton_data_padded = skeleton_data_padded.reshape(1, MAX_SEQUENCE_LENGTH, 34)  # Assuming that the skeleton data has 34 features per timestep
    
    # 이제 패딩된 데이터를 사용하여 모델에서 예측
    prediction = model.predict(skeleton_data_padded)
    
    # 출력: skeleton_data_padded의 shape 및 데이터 타입
    # print("Skeleton data shape:", skeleton_data_padded.shape)
    # print("Skeleton data type:", skeleton_data_padded.dtype)
    
    #확률값 출력
    print("Prediction probabilities:", prediction[0])
    
    walk_type = np.argmax(prediction, axis=1)
    walk_labels = ["Parkinson's Walk", "Shuffling Walk", "Normal Walk"]
    return walk_labels[walk_type[0]]

def select_keypoints(kpts, remove_columns):
    # 모든 keypoints의 컬럼명 리스트를 여기에 적어주세요
    all_columns = ['nose-x', 'nose-y', "nose-conf",
            'left-eye-x', 'left-eye-y', "left-eye-conf",
            'right-eye-x', 'right-eye-y', "right-eye-conf",
            'left-ear-x', 'left-ear-y', "left-ear-conf",
            'right-ear-x', 'right-ear-y', "right-ear-conf",
            'left-shoulder-x', 'left-shoulder-y', "left-shoulder-conf",
            'right-shoulder-x', 'right-shoulder-y', "right-shoulder-conf",
            'left-elbow-x', 'left-elbow-y', "left-elbow-conf",
            'right-elbow-x', 'right-elbow-y', "right-elbow-conf",
            'left-hand-x', 'left-hand-y', "left-hand-conf",
            'right-hand-x', 'right-hand-y', "right-hand-conf",
            'left-hip-x', 'left-hip-y', "left-hip-conf",
            'right-hip-x', 'right-hip-y', "right-hip-conf",
            'left-knee-x', 'left-knee-y', "left-knee-conf",
            'right-knee-x', 'right-knee-y', "right-knee-conf",
            'left-foot-x', 'left-foot-y', "left-foot-conf",
            'right-foot-x', 'right-foot-y', "right-foot-conf"]
    
    indices_to_remove = [all_columns.index(col) for col in remove_columns]
    return [kpts[i] for i in range(len(kpts)) if i not in indices_to_remove]


def visualize(tracked_dets, im0, model, imgsz, stride, device, half, names, h5_model):
    bbox_xyxy = tracked_dets[:, :4]
    identities = tracked_dets[:, -1]
    categories = tracked_dets[:, 4]
    
    for idx, box in enumerate(bbox_xyxy):
        cat = int(categories[idx]) if categories is not None else 0
        if cat != 0:
            continue
        
        id = int(identities[idx]) if identities is not None else 0
        x1, y1, x2, y2 = [int(x) for x in box]
        obj = im0[y1:y2, x1:x2]
        if not obj.shape[0] or not obj.shape[1]:
            continue
        
        d = PoseLoadImages(obj, imgsz, stride)
        kpts, obj = detect(d, model, device, half, xy=[x1, y1])
        if kpts is None:
            continue
            
        # Print keypoints and skeleton_data for debugging
        print("Keypoints for frame:", kpts)
        
        # 여기에서 kpts 값을 필터링
        remove_columns = ["nose-conf", "left-eye-conf", "right-eye-conf", "left-ear-conf", 
                          "right-ear-conf", "left-shoulder-conf", "right-shoulder-conf", 
                          "left-elbow-conf", "right-elbow-conf", "left-hand-conf", 
                          "right-hand-conf", "left-hip-conf", "right-hip-conf", 
                          "left-knee-conf", "right-knee-conf", "left-foot-conf", "right-foot-conf"]

        kpts = select_keypoints(kpts, remove_columns)
        
        skeleton_data = np.array(kpts).reshape(1, -1)  # Assuming you are reshaping the data before feeding to model
        print("Skeleton data for frame:", skeleton_data)

        # 이제 필터링된 kpts 값을 .h5 모델에 입력

        # Predict walk type based on keypoints
        walk_label = predict_walk_type_with_confidence(h5_model, kpts)
        
        # Draw the prediction result on the video frame
        label = f"ID: {id} Type: {walk_label}"
        im0 = cv2.putText(im0, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2, cv2.LINE_AA)
        
    draw_boxes(im0, bbox_xyxy, identities, categories, names)
    return im0

def main(source):
    device = 'cpu'
    img_size, conf_thres, iou_thres = 640, 0.25, 0.45
    view_img, save_json = False, True
    save_img = not source.endswith('.txt')
    webcam = source.isnumeric() or source.endswith('.txt') or source.lower().startswith(('rtsp://', 'rtmp://', 'http://', 'https://'))
    # Initialize SORT tracker and save directory
    sort_tracker = Sort(max_age=5, min_hits=2, iou_threshold=0.2)
    save_dir = Path(increment_path(Path('output') / 'obj', exist_ok=False))
    save_dir.mkdir(parents=True, exist_ok=True)
    # Initialize device and model
    device = select_device(device)
    half = device.type != 'cpu'
    model, stride, imgsz = model_load('yolov7.pt', device, img_size)
    model_, stride_, imgsz_ = model_load('yolov7-w6-pose.pt', device, img_size)
    model = TracedModel(model, device, img_size)
    if half:
        model.half()
        model_.half()
    # Load the h5 model for walk prediction
    h5_model_path = "/Users/jihoon/venvs/skeleton-rnn/best_model_val_loss.h5"
    h5_model = tf.keras.models.load_model(h5_model_path)
    
    vid_path, vid_writer = None, None
    if webcam:
        dataset = LoadStreams(source, img_size=imgsz, stride=stride)
    else:
        dataset = LoadImages(source, img_size=imgsz, stride=stride)
    names = model.module.names if hasattr(model, 'module') else model.names
    if device.type != 'cpu':
        model(torch.zeros(1, 3, imgsz, imgsz).to(device).type_as(next(model.parameters())))
        model_(torch.zeros(1, 3, imgsz_, imgsz_).to(device).type_as(next(model_.parameters())))
    t0 = time.time()
    nf = 0
    results = {}
    for path, img, im0s, vid_cap in dataset:
        nf += 1
        img = img_prep(img, device, half)
        t1 = time_synchronized()
        pred = model(img, augment=False)[0]
        t2 = time_synchronized()
        pred = non_max_suppression(pred, conf_thres, iou_thres, classes=0)
        t3 = time_synchronized()
        for i, det in enumerate(pred):
            if webcam:
                p, s, im0, frame = path[i], '%g: ' % i, im0s[i].copy(), dataset.count
            else:
                p, s, im0, frame = path, '', im0s, getattr(dataset, 'frame', 0)
            p = Path(p)
            save_path = str(save_dir / p.name)
            if len(det):
                tracked_dets = track(det, img, im0, sort_tracker)
                if len(tracked_dets) > 0:
                    results = visualize(tracked_dets, im0, model_, imgsz_, stride_, device, half, names, h5_model)
            else:
                tracked_dets = sort_tracker.update()
        print(f'Done. ({(1E3 * (t2 - t1)):.1f}ms) Inference, ({(1E3 * (t3 - t2)):.1f}ms) NMS')
        if view_img:
            view_image(p, im0)
        if save_img:
            if dataset.mode == 'image':
                cv2.imwrite(save_path, im0)
            else:
                if vid_path != save_path:
                    vid_path = save_path
                    if isinstance(vid_writer, cv2.VideoWriter):
                        vid_writer.release()
                    if vid_cap:
                        fps = vid_cap.get(cv2.CAP_PROP_FPS)
                        w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                        h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                    else:
                        fps, w, h = 30, im0.shape[1], im0.shape[0]
                        save_path += '.mp4'
                    vid_writer = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))
                vid_writer.write(im0)
    if save_json:
        t4 = time.time()
        results['tag'] = {'time': t4-t0,
                          'num of frame': nf,
                          'total detected': len(results.keys()),
                          'frame/time': nf/(t4-t0)
                          }
        with open(save_path.split('.')[0]+'.json', 'w') as f:
            json.dump(results, f, indent=4)


def convert_json_to_csv(base='./output/'):
    path_list = [base + f for f in os.listdir(base) if os.path.isdir(base + f)]
    labels = ['nose-x', 'nose-y',
            'left-eye-x', 'left-eye-y',
            'right-eye-x', 'right-eye-y',
            'left-ear-x', 'left-ear-y',
            'right-ear-x', 'right-ear-y',
            'left-shoulder-x', 'left-shoulder-y',
            'right-shoulder-x', 'right-shoulder-y',
            'left-elbow-x', 'left-elbow-y',
            'right-elbow-x', 'right-elbow-y',
            'left-hand-x', 'left-hand-y',
            'right-hand-x', 'right-hand-y',
            'left-hip-x', 'left-hip-y',
            'right-hip-x', 'right-hip-y',
            'left-knee-x', 'left-knee-y',
            'right-knee-x', 'right-knee-y',
            'left-foot-x', 'left-foot-y',
            'right-foot-x', 'right-foot-y']  # Use the full labels list you provided before
    for path in path_list:
        files = [file for file in os.listdir(path) if file.endswith('.json')]
        for file in files:
            name = file.split('.')[0]
            with open(f'{path}/{file}', 'r') as j:
                data = json.load(j)
                frame = data['tag']['num of frame']
                for key in data.keys():
                    if len(data[key]) < (frame*0.5):
                        continue
                    with open(f'{path}/{name}-{key}.csv', 'w', newline='') as c:
                        w = csv.writer(c)
                        w.writerow(labels)
                        for kpts in data[key]:
                            w.writerow(kpts)


def process_video_and_visualize(source):
    with torch.no_grad():
        main(source)
    convert_json_to_csv()
    h5_model_path = "/Users/jihoon/venvs/skeleton-rnn/best_model_val_loss.h5"
    h5_model = tf.keras.models.load_model(h5_model_path)
    base = './output/'
    path_list = [base + f for f in os.listdir(base) if os.path.isdir(base + f)]
    for path in path_list:
        files = [file for file in os.listdir(path) if file.endswith('.csv')]
        for file in files:
            skeleton_data = np.loadtxt(f'{path}/{file}', delimiter=',', skiprows=1)
            predictions = predict_walk_type(h5_model, skeleton_data)
            # Add the prediction results on the video or save it separately.
            # ...


if __name__ == '__main__':
    video_source = '/Users/jihoon/venvs/skeleton-rnn/input_data'
    process_video_and_visualize(video_source)
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/27 (1/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (258.7ms) Inference, (0.4ms) NMS
# video 1/27 (2/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (203.5ms) Inference, (0.4ms) NMS
# video 1/27 (3/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (185.5ms) Inference, (0.4ms) NMS
# video 1/27 (4/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (180.8ms) Inference, (0.4ms) NMS
# video 1/27 (5/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (193.0ms) Inference, (0.4ms) NMS
# video 1/27 (6/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (188.5ms) Inference, (0.4ms) NMS
# video 1/27 (7/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (177.5ms) Inference, (0.4ms) NMS
# video 1/27 (8/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (179.3ms) Inference, (0.4ms) NMS
# video 1/27 (9/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (182.2ms) Inference, (0.6ms) NMS
# video 1/27 (10/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (177.3ms) Inference, (0.4ms) NMS
# video 1/27 (11/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (180.8ms) Inference, (0.4ms) NMS
# video 1/27 (12/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (177.2ms) Inference, (0.4ms) NMS
# video 1/27 (13/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (178.3ms) Inference, (0.4ms) NMS
# video 1/27 (14/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (178.8ms) Inference, (0.5ms) NMS
# video 1/27 (15/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [2197.009994506836, 798.7965993881226, 0.04505976662039757, 2199.7479705810547, 797.3248405456543, 0.02792232111096382, 2195.1149826049805, 797.2972784042358, 0.029867054894566536, 2203.60262298584, 798.3136987686157, 0.12318145483732224, 2193.342710494995, 796.2482986450195, 0.06738774478435516, 2206.710517883301, 807.3030891418457, 0.3382064700126648, 2187.4260330200195, 806.3344955444336, 0.3987405598163605, 2188.3762950897217, 814.1113395690918, 0.21766343712806702, 2177.7016277313232, 819.645824432373, 0.2039058804512024, 2177.8530950546265, 817.9265041351318, 0.14259406924247742, 2169.585102558136, 831.8582420349121, 0.13933604955673218, 2202.9715881347656, 832.4679069519043, 0.5843728184700012, 2186.881113052368, 832.0554275512695, 0.60523921251297, 2203.6821098327637, 860.2116012573242, 0.13954028487205505, 2187.2165031433105, 860.2263488769531, 0.13943204283714294, 2208.2078971862793, 856.3910369873047, 0.03658386692404747, 2188.9482402801514, 856.4460372924805, 0.0358596034348011]
# Skeleton data for frame: [[       2197       798.8      2199.7      797.32      2195.1       797.3      2203.6      798.31      2193.3      796.25      2206.7       807.3      2187.4      806.33      2188.4      814.11      2177.7      819.65      2177.9      817.93      2169.6      831.86        2203      832.47      2186.9      832.06
#        2203.7      860.21      2187.2      860.23      2208.2      856.39      2188.9      856.45]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [2197.009994506836, 798.7965993881226, 2199.7479705810547, 797.3248405456543, 2195.1149826049805, 797.2972784042358, 2203.60262298584, 798.3136987686157, 2193.342710494995, 796.2482986450195]
# 2023-10-01 17:23:48.076151: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 1s 573ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25507     0.32063      0.4243]
# Done. (209.9ms) Inference, (0.5ms) NMS
# video 1/27 (16/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (189.2ms) Inference, (0.5ms) NMS
# video 1/27 (17/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (185.6ms) Inference, (0.4ms) NMS
# video 1/27 (18/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (183.2ms) Inference, (0.4ms) NMS
# video 1/27 (19/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (198.3ms) Inference, (0.4ms) NMS
# video 1/27 (20/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (199.2ms) Inference, (0.5ms) NMS
# video 1/27 (21/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (196.8ms) Inference, (0.5ms) NMS
# video 1/27 (22/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (197.3ms) Inference, (0.8ms) NMS
# video 1/27 (23/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (183.4ms) Inference, (0.5ms) NMS
# video 1/27 (24/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [2204.4784545898438, 820.469804763794, 0.6413359642028809, 2205.2601776123047, 816.4456233978271, 0.2508300244808197, 2199.9281616210938, 816.1898975372314, 0.7007696628570557, 2204.397960662842, 818.2559299468994, 0.018314706161618233, 2185.9705295562744, 818.6067562103271, 0.7116871476173401, 2210.1481170654297, 840.7116851806641, 0.37717822194099426, 2171.6042518615723, 841.1281509399414, 0.6108248829841614, 2215.188316345215, 858.304573059082, 0.03938903659582138, 2166.2365283966064, 861.386474609375, 0.14694541692733765, 2213.5023498535156, 853.1325416564941, 0.0529213584959507, 2164.8377556800842, 842.1416816711426, 0.17129376530647278, 2203.791519165039, 864.431999206543, 0.03177997097373009, 2179.677755355835, 865.2811508178711, 0.04917247220873833, 2203.072395324707, 864.1262588500977, 0.009928742423653603, 2189.0602264404297, 865.6775131225586, 0.015335322357714176, 2198.756660461426, 862.5194854736328, 0.008502214215695858, 2186.9895191192627, 862.7802734375, 0.01088511012494564]
# Skeleton data for frame: [[     2204.5      820.47      2205.3      816.45      2199.9      816.19      2204.4      818.26        2186      818.61      2210.1      840.71      2171.6      841.13      2215.2       858.3      2166.2      861.39      2213.5      853.13      2164.8      842.14      2203.8      864.43      2179.7      865.28
#        2203.1      864.13      2189.1      865.68      2198.8      862.52        2187      862.78]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [2204.4784545898438, 820.469804763794, 2205.2601776123047, 816.4456233978271, 2199.9281616210938, 816.1898975372314, 2204.397960662842, 818.2559299468994, 2185.9705295562744, 818.6067562103271]
# 1/1 [==============================] - 0s 133ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25507     0.32063      0.4243]
# Done. (195.3ms) Inference, (0.5ms) NMS
# video 1/27 (25/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (190.3ms) Inference, (0.4ms) NMS
# video 1/27 (26/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (183.5ms) Inference, (0.4ms) NMS
# video 1/27 (27/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (200.4ms) Inference, (0.4ms) NMS
# video 1/27 (28/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (194.1ms) Inference, (0.4ms) NMS
# video 1/27 (29/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (202.2ms) Inference, (0.5ms) NMS
# video 1/27 (30/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (200.7ms) Inference, (0.7ms) NMS
# video 1/27 (31/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (197.7ms) Inference, (0.6ms) NMS
# video 1/27 (32/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (215.5ms) Inference, (0.4ms) NMS
# video 1/27 (33/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (189.8ms) Inference, (0.4ms) NMS
# video 1/27 (34/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (183.7ms) Inference, (0.4ms) NMS
# video 1/27 (35/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (185.9ms) Inference, (0.4ms) NMS
# video 1/27 (36/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (185.7ms) Inference, (0.4ms) NMS
# video 1/27 (37/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (185.2ms) Inference, (0.4ms) NMS
# video 1/27 (38/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (187.2ms) Inference, (0.4ms) NMS
# video 1/27 (39/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (194.7ms) Inference, (0.5ms) NMS
# video 1/27 (40/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (202.4ms) Inference, (0.4ms) NMS
# video 1/27 (41/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (188.1ms) Inference, (0.4ms) NMS
# video 1/27 (42/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (185.7ms) Inference, (0.4ms) NMS
# video 1/27 (43/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (184.2ms) Inference, (0.4ms) NMS
# video 1/27 (44/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (192.1ms) Inference, (0.4ms) NMS
# video 1/27 (45/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (200.8ms) Inference, (0.5ms) NMS
# video 1/27 (46/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (194.3ms) Inference, (0.4ms) NMS
# video 1/27 (47/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (203.5ms) Inference, (0.4ms) NMS
# video 1/27 (48/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (199.9ms) Inference, (0.4ms) NMS
# video 1/27 (49/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (189.4ms) Inference, (0.4ms) NMS
# video 1/27 (50/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (183.1ms) Inference, (0.4ms) NMS
# video 1/27 (51/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (189.5ms) Inference, (0.7ms) NMS
# video 1/27 (52/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (197.6ms) Inference, (0.4ms) NMS
# video 1/27 (53/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (199.4ms) Inference, (0.4ms) NMS
# video 1/27 (54/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (199.8ms) Inference, (0.9ms) NMS
# video 1/27 (55/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (185.6ms) Inference, (0.4ms) NMS
# video 1/27 (56/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (186.8ms) Inference, (0.4ms) NMS
# video 1/27 (57/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (190.1ms) Inference, (0.7ms) NMS
# video 1/27 (58/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Done. (192.1ms) Inference, (0.5ms) NMS
# video 1/27 (59/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1560.2669982910156, 1079.2630767822266, 0.40450865030288696, 1564.4449462890625, 1065.5995407104492, 0.39262649416923523, 1565.654296875, 1064.9035110473633, 0.01159006729722023, 1598.5874328613281, 1071.1070175170898, 0.8352635502815247, 1643.2040710449219, 1059.7515335083008, 0.03420662507414818, 1600.3244323730469, 1180.5175323486328, 0.8995495438575745, 1654.3765563964844, 1139.4898071289062, 0.5546382665634155, 1501.3043670654297, 1245.4163818359375, 0.9440534710884094, 1520.5152435302734, 1236.5972595214844, 0.33215832710266113, 1386.2447509765625, 1215.3783264160156, 0.9326162338256836, 1387.1493682861328, 1220.4198608398438, 0.46276241540908813, 1566.7828063964844, 1409.171875, 0.8169686794281006, 1607.4405822753906, 1389.7347412109375, 0.5939292311668396, 1542.7242279052734, 1511.509765625, 0.12321289628744125, 1558.7752532958984, 1507.2406005859375, 0.03706604614853859, 1533.7796173095703, 1495.8650512695312, 0.012833133339881897, 1544.4759216308594, 1498.7821655273438, 0.005259315017610788]
# Skeleton data for frame: [[     1560.3      1079.3      1564.4      1065.6      1565.7      1064.9      1598.6      1071.1      1643.2      1059.8      1600.3      1180.5      1654.4      1139.5      1501.3      1245.4      1520.5      1236.6      1386.2      1215.4      1387.1      1220.4      1566.8      1409.2      1607.4      1389.7
#        1542.7      1511.5      1558.8      1507.2      1533.8      1495.9      1544.5      1498.8]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1560.2669982910156, 1079.2630767822266, 1564.4449462890625, 1065.5995407104492, 1565.654296875, 1064.9035110473633, 1598.5874328613281, 1071.1070175170898, 1643.2040710449219, 1059.7515335083008]
# 1/1 [==============================] - 0s 140ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25738     0.32393     0.41869]
# Done. (203.3ms) Inference, (0.8ms) NMS
# video 1/27 (60/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1579.4335479736328, 1102.9074401855469, 0.4606766104698181, 1587.3076477050781, 1087.7714767456055, 0.3844243288040161, 1579.7516021728516, 1087.6326446533203, 0.03811325132846832, 1623.7035827636719, 1085.105567932129, 0.4314146637916565, 1608.5592041015625, 1083.696762084961, 0.1207229495048523, 1635.8360595703125, 1174.1597595214844, 0.44341129064559937, 1617.1109924316406, 1153.6179656982422, 0.8666491508483887, 1573.3547821044922, 1247.7022399902344, 0.2683923840522766, 1504.3462219238281, 1236.6427612304688, 0.8544086217880249, 1534.1344757080078, 1218.4451904296875, 0.34735792875289917, 1378.6118774414062, 1217.2192077636719, 0.8241726160049438, 1585.6657409667969, 1410.7942199707031, 0.46684208512306213, 1560.7771606445312, 1400.5413208007812, 0.7055003046989441, 1558.7144165039062, 1509.216796875, 0.050761282444000244, 1545.6498413085938, 1503.802490234375, 0.10138197243213654, 1535.505615234375, 1519.5615844726562, 0.01060833316296339, 1516.2435607910156, 1515.9562377929688, 0.016765717417001724]
# Skeleton data for frame: [[     1579.4      1102.9      1587.3      1087.8      1579.8      1087.6      1623.7      1085.1      1608.6      1083.7      1635.8      1174.2      1617.1      1153.6      1573.4      1247.7      1504.3      1236.6      1534.1      1218.4      1378.6      1217.2      1585.7      1410.8      1560.8      1400.5
#        1558.7      1509.2      1545.6      1503.8      1535.5      1519.6      1516.2        1516]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1579.4335479736328, 1102.9074401855469, 1587.3076477050781, 1087.7714767456055, 1579.7516021728516, 1087.6326446533203, 1623.7035827636719, 1085.105567932129, 1608.5592041015625, 1083.696762084961]
# 1/1 [==============================] - 0s 134ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25746     0.32405     0.41849]
# Done. (195.4ms) Inference, (0.5ms) NMS
# video 1/27 (61/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1542.9600982666016, 1105.9376983642578, 0.1719168722629547, 1542.7601165771484, 1094.0986785888672, 0.2874244451522827, 1542.9322967529297, 1090.8103637695312, 0.002719275187700987, 1590.4410705566406, 1088.5174102783203, 0.8464639782905579, 1618.9202575683594, 1068.318344116211, 0.021747009828686714, 1604.0347595214844, 1192.7279052734375, 0.8248564600944519, 1641.4884643554688, 1138.6262664794922, 0.7131774425506592, 1501.0105895996094, 1236.5737915039062, 0.7971235513687134, 1517.4605712890625, 1228.7955017089844, 0.46802905201911926, 1375.8270111083984, 1213.2411193847656, 0.8253052234649658, 1373.8316230773926, 1216.9656982421875, 0.5465784668922424, 1544.79736328125, 1354.9317626953125, 0.21157187223434448, 1562.8540802001953, 1330.150146484375, 0.1714688539505005, 1459.5745391845703, 1322.6152038574219, 0.022961638867855072, 1442.4392547607422, 1301.8061828613281, 0.014120792970061302, 1466.8606567382812, 1315.8224487304688, 0.008736084215342999, 1450.2338333129883, 1298.7254943847656, 0.006492977030575275]
# Skeleton data for frame: [[       1543      1105.9      1542.8      1094.1      1542.9      1090.8      1590.4      1088.5      1618.9      1068.3        1604      1192.7      1641.5      1138.6        1501      1236.6      1517.5      1228.8      1375.8      1213.2      1373.8        1217      1544.8      1354.9      1562.9      1330.2
#        1459.6      1322.6      1442.4      1301.8      1466.9      1315.8      1450.2      1298.7]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1542.9600982666016, 1105.9376983642578, 1542.7601165771484, 1094.0986785888672, 1542.9322967529297, 1090.8103637695312, 1590.4410705566406, 1088.5174102783203, 1618.9202575683594, 1068.318344116211]
# 1/1 [==============================] - 0s 137ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25766     0.32436     0.41799]
# Done. (201.0ms) Inference, (0.5ms) NMS
# video 1/27 (62/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1618.6915893554688, 1104.5552978515625, 0.18822386860847473, 1615.3488159179688, 1087.8382873535156, 0.007875216193497181, 1619.7704467773438, 1090.8453826904297, 0.2190323770046234, 1563.9444274902344, 1080.3212661743164, 0.1425374150276184, 1592.107666015625, 1082.539047241211, 0.7529704570770264, 1578.7281494140625, 1168.7001953125, 0.8813621997833252, 1587.7812805175781, 1161.8656921386719, 0.9230979084968567, 1496.4437408447266, 1228.2586669921875, 0.8123639822006226, 1495.8434143066406, 1231.7041015625, 0.8596428632736206, 1368.1943168640137, 1208.8353729248047, 0.7947981357574463, 1371.335247039795, 1212.293716430664, 0.8522908687591553, 1570.550521850586, 1373.749755859375, 0.7386503219604492, 1571.344253540039, 1368.1513977050781, 0.7607121467590332, 1543.1840057373047, 1454.4048461914062, 0.06996668875217438, 1535.9122161865234, 1451.341064453125, 0.06826868653297424, 1519.0340423583984, 1431.189453125, 0.00847933255136013, 1523.9060821533203, 1434.3727111816406, 0.008088575676083565]
# Skeleton data for frame: [[     1618.7      1104.6      1615.3      1087.8      1619.8      1090.8      1563.9      1080.3      1592.1      1082.5      1578.7      1168.7      1587.8      1161.9      1496.4      1228.3      1495.8      1231.7      1368.2      1208.8      1371.3      1212.3      1570.6      1373.7      1571.3      1368.2
#        1543.2      1454.4      1535.9      1451.3        1519      1431.2      1523.9      1434.4]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1618.6915893554688, 1104.5552978515625, 1615.3488159179688, 1087.8382873535156, 1619.7704467773438, 1090.8453826904297, 1563.9444274902344, 1080.3212661743164, 1592.107666015625, 1082.539047241211]
# 1/1 [==============================] - 0s 130ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25747     0.32407     0.41847]
# Done. (189.2ms) Inference, (0.5ms) NMS
# video 1/27 (63/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1533.0068969726562, 1098.3305130004883, 0.48362410068511963, 1542.7784576416016, 1085.1772689819336, 0.47007864713668823, 1534.9106140136719, 1081.694450378418, 0.012622774578630924, 1601.7539672851562, 1079.985610961914, 0.6526551246643066, 1616.3728942871094, 1066.6645050048828, 0.022348839789628983, 1601.5363159179688, 1184.7821044921875, 0.8237550854682922, 1640.8046569824219, 1142.2718048095703, 0.6247608661651611, 1482.1491088867188, 1231.7531280517578, 0.9054397940635681, 1496.100601196289, 1221.937026977539, 0.5378198623657227, 1364.7491912841797, 1210.8839263916016, 0.9201768040657043, 1364.5023880004883, 1218.898178100586, 0.7003732919692993, 1591.8583984375, 1424.0289611816406, 0.7091097235679626, 1609.2901916503906, 1400.4900512695312, 0.5723603367805481, 1554.0734405517578, 1504.8218383789062, 0.08957962691783905, 1550.5705261230469, 1494.0773315429688, 0.041752975434064865, 1530.768539428711, 1490.1738586425781, 0.012247209437191486, 1524.3309020996094, 1487.1776428222656, 0.007344991900026798]
# Skeleton data for frame: [[       1533      1098.3      1542.8      1085.2      1534.9      1081.7      1601.8        1080      1616.4      1066.7      1601.5      1184.8      1640.8      1142.3      1482.1      1231.8      1496.1      1221.9      1364.7      1210.9      1364.5      1218.9      1591.9        1424      1609.3      1400.5
#        1554.1      1504.8      1550.6      1494.1      1530.8      1490.2      1524.3      1487.2]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1533.0068969726562, 1098.3305130004883, 1542.7784576416016, 1085.1772689819336, 1534.9106140136719, 1081.694450378418, 1601.7539672851562, 1079.985610961914, 1616.3728942871094, 1066.6645050048828]
# 1/1 [==============================] - 0s 131ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25759     0.32426     0.41815]
# Done. (193.0ms) Inference, (0.5ms) NMS
# video 1/27 (64/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1551.6626434326172, 1114.6952667236328, 0.19247686862945557, 1549.1717071533203, 1100.758804321289, 0.2141634225845337, 1550.2345733642578, 1099.678092956543, 0.003934405744075775, 1587.7098388671875, 1089.3400039672852, 0.7067927718162537, 1611.8027954101562, 1079.872169494629, 0.07092085480690002, 1610.04833984375, 1183.5745544433594, 0.7251476645469666, 1634.9372863769531, 1138.903060913086, 0.845024049282074, 1495.2765197753906, 1239.7525634765625, 0.6051905751228333, 1511.7699737548828, 1223.5594787597656, 0.7300649285316467, 1358.7635917663574, 1217.5536651611328, 0.5401105880737305, 1360.9640922546387, 1215.6628723144531, 0.6483504772186279, 1559.1248016357422, 1380.2195739746094, 0.7697415351867676, 1560.1192321777344, 1360.3301696777344, 0.8289798498153687, 1531.0650024414062, 1530.1752319335938, 0.17427584528923035, 1529.0150604248047, 1522.58056640625, 0.19819624722003937, 1519.1241302490234, 1548.0, 0.025573892518877983, 1503.1877746582031, 1538.7734375, 0.02858990989625454]
# Skeleton data for frame: [[     1551.7      1114.7      1549.2      1100.8      1550.2      1099.7      1587.7      1089.3      1611.8      1079.9        1610      1183.6      1634.9      1138.9      1495.3      1239.8      1511.8      1223.6      1358.8      1217.6        1361      1215.7      1559.1      1380.2      1560.1      1360.3
#        1531.1      1530.2        1529      1522.6      1519.1        1548      1503.2      1538.8]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1551.6626434326172, 1114.6952667236328, 1549.1717071533203, 1100.758804321289, 1550.2345733642578, 1099.678092956543, 1587.7098388671875, 1089.3400039672852, 1611.8027954101562, 1079.872169494629]
# 1/1 [==============================] - 0s 133ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25769     0.32441      0.4179]
# Done. (183.9ms) Inference, (0.5ms) NMS
# video 1/27 (65/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1541.5998840332031, 1104.3623275756836, 0.191146582365036, 1541.6524658203125, 1090.820785522461, 0.206105574965477, 1542.6178131103516, 1089.0007858276367, 0.004615564364939928, 1580.2782592773438, 1087.4911193847656, 0.645388126373291, 1623.4162902832031, 1072.060646057129, 0.07350531965494156, 1596.0924072265625, 1191.1229553222656, 0.6798638105392456, 1646.5858764648438, 1142.8095703125, 0.881899893283844, 1533.4952087402344, 1304.3287048339844, 0.43969717621803284, 1506.4023132324219, 1225.2328491210938, 0.7686137557029724, 1373.0188598632812, 1285.1852722167969, 0.3879224956035614, 1358.170394897461, 1217.425033569336, 0.6806105971336365, 1582.6387939453125, 1411.5373229980469, 0.5818548798561096, 1609.97900390625, 1389.5152893066406, 0.7291574478149414, 1522.2175903320312, 1519.26611328125, 0.10780326277017593, 1535.7589874267578, 1506.4796752929688, 0.1492559164762497, 1489.961166381836, 1551.4659423828125, 0.022292429581284523, 1487.7789306640625, 1541.2183227539062, 0.0284197349101305]
# Skeleton data for frame: [[     1541.6      1104.4      1541.7      1090.8      1542.6        1089      1580.3      1087.5      1623.4      1072.1      1596.1      1191.1      1646.6      1142.8      1533.5      1304.3      1506.4      1225.2        1373      1285.2      1358.2      1217.4      1582.6      1411.5        1610      1389.5
#        1522.2      1519.3      1535.8      1506.5        1490      1551.5      1487.8      1541.2]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1541.5998840332031, 1104.3623275756836, 1541.6524658203125, 1090.820785522461, 1542.6178131103516, 1089.0007858276367, 1580.2782592773438, 1087.4911193847656, 1623.4162902832031, 1072.060646057129]
# 1/1 [==============================] - 0s 133ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25768      0.3244     0.41792]
# Done. (185.7ms) Inference, (0.4ms) NMS
# video 1/27 (66/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1545.2308654785156, 1110.6451263427734, 0.2588936984539032, 1547.9616241455078, 1095.5899505615234, 0.24724367260932922, 1547.0142059326172, 1094.6153182983398, 0.007980769500136375, 1591.0619812011719, 1089.7516021728516, 0.533937394618988, 1607.87255859375, 1083.5091094970703, 0.05520159751176834, 1611.7653503417969, 1188.6595153808594, 0.4318408966064453, 1629.5950622558594, 1151.4870910644531, 0.7917068004608154, 1549.0908203125, 1303.0385131835938, 0.28827986121177673, 1522.9681396484375, 1227.6875, 0.7496524453163147, 1376.1961212158203, 1324.9167175292969, 0.28973254561424255, 1361.8688201904297, 1222.6576843261719, 0.6892478466033936, 1581.1414794921875, 1427.3048095703125, 0.6101138591766357, 1577.0855102539062, 1404.8872680664062, 0.7803934216499329, 1547.3580017089844, 1552.2348022460938, 0.1629221886396408, 1545.7294006347656, 1530.6736450195312, 0.2527580261230469, 1508.8524627685547, 1557.9893188476562, 0.035253528505563736, 1486.3741912841797, 1542.0909423828125, 0.05030559375882149]
# Skeleton data for frame: [[     1545.2      1110.6        1548      1095.6        1547      1094.6      1591.1      1089.8      1607.9      1083.5      1611.8      1188.7      1629.6      1151.5      1549.1        1303        1523      1227.7      1376.2      1324.9      1361.9      1222.7      1581.1      1427.3      1577.1      1404.9
#        1547.4      1552.2      1545.7      1530.7      1508.9        1558      1486.4      1542.1]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1545.2308654785156, 1110.6451263427734, 1547.9616241455078, 1095.5899505615234, 1547.0142059326172, 1094.6153182983398, 1591.0619812011719, 1089.7516021728516, 1607.87255859375, 1083.5091094970703]
# 1/1 [==============================] - 0s 136ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25769     0.32441      0.4179]
# Done. (189.1ms) Inference, (0.5ms) NMS
# video 1/27 (67/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1590.0626220703125, 1118.3645782470703, 0.06530355662107468, 1589.6404113769531, 1102.4093933105469, 0.02735155262053013, 1594.4613647460938, 1102.3592987060547, 0.020118827000260353, 1584.7361145019531, 1095.745704650879, 0.18052160739898682, 1594.0818176269531, 1095.3055419921875, 0.5513875484466553, 1590.8591918945312, 1190.138442993164, 0.6760150790214539, 1580.3060302734375, 1174.8577880859375, 0.9271130561828613, 1517.190185546875, 1304.8983459472656, 0.39661121368408203, 1476.7865295410156, 1229.5516357421875, 0.8966394662857056, 1413.2502059936523, 1464.9863586425781, 0.3081238567829132, 1348.08203125, 1226.9693908691406, 0.843061625957489, 1604.5765075683594, 1422.9277038574219, 0.570762574672699, 1590.005615234375, 1407.3074035644531, 0.7792934775352478, 1511.6023254394531, 1359.9557800292969, 0.5805343985557556, 1486.6736602783203, 1354.7813415527344, 0.7493385672569275, 1424.9591369628906, 1547.1134643554688, 0.44447553157806396, 1422.9334106445312, 1535.7679443359375, 0.57797771692276]
# Skeleton data for frame: [[     1590.1      1118.4      1589.6      1102.4      1594.5      1102.4      1584.7      1095.7      1594.1      1095.3      1590.9      1190.1      1580.3      1174.9      1517.2      1304.9      1476.8      1229.6      1413.3        1465      1348.1        1227      1604.6      1422.9        1590      1407.3
#        1511.6        1360      1486.7      1354.8        1425      1547.1      1422.9      1535.8]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1590.0626220703125, 1118.3645782470703, 1589.6404113769531, 1102.4093933105469, 1594.4613647460938, 1102.3592987060547, 1584.7361145019531, 1095.745704650879, 1594.0818176269531, 1095.3055419921875]
# 1/1 [==============================] - 0s 132ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25768      0.3244     0.41792]
# Done. (187.1ms) Inference, (0.5ms) NMS
# video 1/27 (68/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1533.6237030029297, 1117.7456665039062, 0.2467818260192871, 1534.5018463134766, 1103.9781036376953, 0.2771203815937042, 1533.8716125488281, 1102.9938049316406, 0.006490806117653847, 1585.0648498535156, 1087.3573760986328, 0.628852903842926, 1592.8778686523438, 1082.1141204833984, 0.06867962330579758, 1621.1689758300781, 1204.6637420654297, 0.47885069251060486, 1606.1378784179688, 1149.9651489257812, 0.8423682451248169, 1556.7022094726562, 1385.7507934570312, 0.2732123136520386, 1493.7015533447266, 1228.9962310791016, 0.8135627508163452, 1424.4065704345703, 1539.8401489257812, 0.2887907922267914, 1349.8863677978516, 1222.6190338134766, 0.7826619744300842, 1580.9331665039062, 1414.3849792480469, 0.6146247982978821, 1551.1750793457031, 1377.6925659179688, 0.8066733479499817, 1518.0455017089844, 1497.0006103515625, 0.46278053522109985, 1471.5147399902344, 1454.4324340820312, 0.6298862099647522, 1461.0602569580078, 1592.4223022460938, 0.24182094633579254, 1406.556053161621, 1564.13671875, 0.3371177613735199]
# Skeleton data for frame: [[     1533.6      1117.7      1534.5        1104      1533.9        1103      1585.1      1087.4      1592.9      1082.1      1621.2      1204.7      1606.1        1150      1556.7      1385.8      1493.7        1229      1424.4      1539.8      1349.9      1222.6      1580.9      1414.4      1551.2      1377.7
#          1518        1497      1471.5      1454.4      1461.1      1592.4      1406.6      1564.1]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1533.6237030029297, 1117.7456665039062, 1534.5018463134766, 1103.9781036376953, 1533.8716125488281, 1102.9938049316406, 1585.0648498535156, 1087.3573760986328, 1592.8778686523438, 1082.1141204833984]
# 1/1 [==============================] - 0s 137ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25769     0.32441      0.4179]
# Done. (193.5ms) Inference, (0.5ms) NMS
# video 1/27 (69/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1602.2818298339844, 1133.7119750976562, 0.09946233779191971, 1603.982666015625, 1116.9644317626953, 0.009725729003548622, 1605.034912109375, 1118.0741729736328, 0.10400880128145218, 1571.7787780761719, 1093.5291748046875, 0.04974802955985069, 1581.7447814941406, 1091.1007843017578, 0.6676946878433228, 1578.0847473144531, 1157.0323181152344, 0.672858715057373, 1545.5865478515625, 1140.7060241699219, 0.9309123754501343, 1470.5783996582031, 1224.7433471679688, 0.44905462861061096, 1465.2156677246094, 1220.3870086669922, 0.9065371751785278, 1341.909652709961, 1223.511947631836, 0.48067545890808105, 1343.7462463378906, 1221.8630065917969, 0.8896192908287048, 1599.0056457519531, 1358.703125, 0.6612911820411682, 1566.3447265625, 1344.5530700683594, 0.8289036750793457, 1504.6309661865234, 1480.5613708496094, 0.6123675107955933, 1472.061508178711, 1448.3763427734375, 0.7599878311157227, 1405.6990814208984, 1614.4683837890625, 0.3257165849208832, 1394.0881805419922, 1598.1265258789062, 0.45538732409477234]
# Skeleton data for frame: [[     1602.3      1133.7        1604        1117        1605      1118.1      1571.8      1093.5      1581.7      1091.1      1578.1        1157      1545.6      1140.7      1470.6      1224.7      1465.2      1220.4      1341.9      1223.5      1343.7      1221.9        1599      1358.7      1566.3      1344.6
#        1504.6      1480.6      1472.1      1448.4      1405.7      1614.5      1394.1      1598.1]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1602.2818298339844, 1133.7119750976562, 1603.982666015625, 1116.9644317626953, 1605.034912109375, 1118.0741729736328, 1571.7787780761719, 1093.5291748046875, 1581.7447814941406, 1091.1007843017578]
# 1/1 [==============================] - 0s 139ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25768      0.3244     0.41792]
# Done. (202.3ms) Inference, (0.5ms) NMS
# video 1/27 (70/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1539.736572265625, 1111.5834503173828, 0.48513078689575195, 1541.79736328125, 1095.1353759765625, 0.3509896993637085, 1541.2894592285156, 1095.0010681152344, 0.024776732549071312, 1570.3542785644531, 1084.1044616699219, 0.697871208190918, 1615.3439331054688, 1071.7435836791992, 0.06804678589105606, 1607.6325378417969, 1204.0135955810547, 0.6344543695449829, 1639.4157409667969, 1137.8380432128906, 0.8915852308273315, 1528.8412780761719, 1384.4583740234375, 0.3241834342479706, 1490.077896118164, 1221.1637878417969, 0.8486154079437256, 1434.0533599853516, 1550.7596435546875, 0.3065752387046814, 1336.917137145996, 1225.7212829589844, 0.8140047788619995, 1607.9002075195312, 1417.5774841308594, 0.5411532521247864, 1617.8185119628906, 1379.3290100097656, 0.7773804068565369, 1469.9763641357422, 1493.8453369140625, 0.49829140305519104, 1472.1534881591797, 1472.3109436035156, 0.6785275340080261, 1385.1211471557617, 1630.0126342773438, 0.206291064620018, 1386.5276184082031, 1622.2364501953125, 0.3142087757587433]
# Skeleton data for frame: [[     1539.7      1111.6      1541.8      1095.1      1541.3        1095      1570.4      1084.1      1615.3      1071.7      1607.6        1204      1639.4      1137.8      1528.8      1384.5      1490.1      1221.2      1434.1      1550.8      1336.9      1225.7      1607.9      1417.6      1617.8      1379.3
#          1470      1493.8      1472.2      1472.3      1385.1        1630      1386.5      1622.2]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1539.736572265625, 1111.5834503173828, 1541.79736328125, 1095.1353759765625, 1541.2894592285156, 1095.0010681152344, 1570.3542785644531, 1084.1044616699219, 1615.3439331054688, 1071.7435836791992]
# 1/1 [==============================] - 0s 135ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25769     0.32441      0.4179]
# Done. (205.1ms) Inference, (0.6ms) NMS
# video 1/27 (71/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1416.5309257507324, 1020.9747619628906, 0.06009605899453163, 1413.0690383911133, 1016.2134246826172, 0.004862629342824221, 1417.5864868164062, 1015.0516204833984, 0.1607687920331955, 1393.457540512085, 1022.0482635498047, 0.1825830042362213, 1424.2891731262207, 1018.3955841064453, 0.5824074745178223, 1391.4005374908447, 1051.219009399414, 0.22062520682811737, 1436.548828125, 1042.5065307617188, 0.20808087289333344, 1389.220495223999, 1056.5086364746094, 0.013553979806602001, 1430.6025047302246, 1045.7466125488281, 0.013905431143939495, 1386.491310119629, 1048.3009033203125, 0.008661811240017414, 1426.4089813232422, 1037.7972717285156, 0.00848170556128025, 1401.7197189331055, 1058.410415649414, 0.010556803084909916, 1429.6818046569824, 1055.1243286132812, 0.010676821693778038, 1402.5055084228516, 1044.9248962402344, 0.010192690417170525, 1419.1586875915527, 1042.4148864746094, 0.010137716308236122, 1404.326000213623, 1047.872543334961, 0.01265574712306261, 1411.770622253418, 1046.240478515625, 0.012751808390021324]
# Skeleton data for frame: [[     1416.5        1021      1413.1      1016.2      1417.6      1015.1      1393.5        1022      1424.3      1018.4      1391.4      1051.2      1436.5      1042.5      1389.2      1056.5      1430.6      1045.7      1386.5      1048.3      1426.4      1037.8      1401.7      1058.4      1429.7      1055.1
#        1402.5      1044.9      1419.2      1042.4      1404.3      1047.9      1411.8      1046.2]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1416.5309257507324, 1020.9747619628906, 1413.0690383911133, 1016.2134246826172, 1417.5864868164062, 1015.0516204833984, 1393.457540512085, 1022.0482635498047, 1424.2891731262207, 1018.3955841064453]
# 1/1 [==============================] - 0s 133ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25715     0.32357     0.41928]
# Keypoints for frame: [1533.2828063964844, 1108.313980102539, 0.5104530453681946, 1540.440673828125, 1090.813117980957, 0.38304778933525085, 1532.7386474609375, 1091.4915390014648, 0.033888429403305054, 1578.0444641113281, 1081.9033432006836, 0.6421682834625244, 1583.3814392089844, 1077.4607162475586, 0.0647260770201683, 1632.026611328125, 1184.5013885498047, 0.36682868003845215, 1591.4314575195312, 1151.8418884277344, 0.9062723517417908, 1614.3500671386719, 1309.7524719238281, 0.10947705060243607, 1464.6738891601562, 1220.0186157226562, 0.8752498626708984, 1597.2598876953125, 1387.5499572753906, 0.19149601459503174, 1331.0749473571777, 1219.3275909423828, 0.8381187319755554, 1603.61279296875, 1399.5654907226562, 0.46084558963775635, 1572.0468139648438, 1377.9656677246094, 0.808444082736969, 1479.0767517089844, 1478.2280883789062, 0.47197791934013367, 1465.3373107910156, 1470.9832458496094, 0.7693750858306885, 1379.3948516845703, 1641.5994873046875, 0.2202223837375641, 1380.9136581420898, 1634.698974609375, 0.43024319410324097]
# Skeleton data for frame: [[     1533.3      1108.3      1540.4      1090.8      1532.7      1091.5        1578      1081.9      1583.4      1077.5        1632      1184.5      1591.4      1151.8      1614.4      1309.8      1464.7        1220      1597.3      1387.5      1331.1      1219.3      1603.6      1399.6        1572        1378
#        1479.1      1478.2      1465.3        1471      1379.4      1641.6      1380.9      1634.7]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1533.2828063964844, 1108.313980102539, 1540.440673828125, 1090.813117980957, 1532.7386474609375, 1091.4915390014648, 1578.0444641113281, 1081.9033432006836, 1583.3814392089844, 1077.4607162475586]
# 1/1 [==============================] - 0s 138ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25769     0.32441      0.4179]
# Done. (192.8ms) Inference, (0.6ms) NMS
# video 1/27 (72/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1522.0587158203125, 1104.5282135009766, 0.32515934109687805, 1527.1876525878906, 1087.5131530761719, 0.22718076407909393, 1523.6667785644531, 1088.1510772705078, 0.021097777411341667, 1560.5683898925781, 1075.9202499389648, 0.5552891492843628, 1603.4073486328125, 1066.4823837280273, 0.06453200429677963, 1590.0268859863281, 1187.0992431640625, 0.6101691722869873, 1619.5903930664062, 1141.6024169921875, 0.853181004524231, 1445.8949279785156, 1251.2572937011719, 0.3878224492073059, 1470.116455078125, 1220.7635498046875, 0.7519088387489319, 1336.5104675292969, 1228.0277099609375, 0.4359779357910156, 1331.7887954711914, 1221.522705078125, 0.7616361379623413, 1602.7966003417969, 1398.4551086425781, 0.5413488149642944, 1606.6871948242188, 1376.9170837402344, 0.7118532657623291, 1479.3953247070312, 1459.9415893554688, 0.6202283501625061, 1474.8591918945312, 1441.7164916992188, 0.7129474878311157, 1384.6662063598633, 1656.4347534179688, 0.34156060218811035, 1380.7684478759766, 1643.6035766601562, 0.4282384514808655]
# Skeleton data for frame: [[     1522.1      1104.5      1527.2      1087.5      1523.7      1088.2      1560.6      1075.9      1603.4      1066.5        1590      1187.1      1619.6      1141.6      1445.9      1251.3      1470.1      1220.8      1336.5        1228      1331.8      1221.5      1602.8      1398.5      1606.7      1376.9
#        1479.4      1459.9      1474.9      1441.7      1384.7      1656.4      1380.8      1643.6]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1522.0587158203125, 1104.5282135009766, 1527.1876525878906, 1087.5131530761719, 1523.6667785644531, 1088.1510772705078, 1560.5683898925781, 1075.9202499389648, 1603.4073486328125, 1066.4823837280273]
# 1/1 [==============================] - 0s 132ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25768      0.3244     0.41792]
# Done. (192.0ms) Inference, (0.5ms) NMS
# video 1/27 (73/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1521.7502746582031, 1105.0652618408203, 0.2533603310585022, 1524.09130859375, 1089.6360168457031, 0.21808332204818726, 1523.4825439453125, 1089.8618774414062, 0.014176384545862675, 1553.9862670898438, 1078.534652709961, 0.6151830554008484, 1599.1165771484375, 1068.7105407714844, 0.06309089809656143, 1601.0885314941406, 1171.3524627685547, 0.42338740825653076, 1615.6858825683594, 1135.3755645751953, 0.8703475594520569, 1455.6251831054688, 1252.1713256835938, 0.22149880230426788, 1462.0501861572266, 1214.3246765136719, 0.8395699262619019, 1357.3829727172852, 1247.35546875, 0.31963852047920227, 1326.608497619629, 1220.7045135498047, 0.8301071524620056, 1612.2834777832031, 1384.6812133789062, 0.6509796380996704, 1598.6954956054688, 1361.7733459472656, 0.8686484694480896, 1536.8422241210938, 1523.7493896484375, 0.7568969130516052, 1472.1165313720703, 1484.6707153320312, 0.8907415270805359, 1489.5428161621094, 1695.6179809570312, 0.4737822115421295, 1383.1678085327148, 1657.2933959960938, 0.6692628860473633]
# Skeleton data for frame: [[     1521.8      1105.1      1524.1      1089.6      1523.5      1089.9        1554      1078.5      1599.1      1068.7      1601.1      1171.4      1615.7      1135.4      1455.6      1252.2      1462.1      1214.3      1357.4      1247.4      1326.6      1220.7      1612.3      1384.7      1598.7      1361.8
#        1536.8      1523.7      1472.1      1484.7      1489.5      1695.6      1383.2      1657.3]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1521.7502746582031, 1105.0652618408203, 1524.09130859375, 1089.6360168457031, 1523.4825439453125, 1089.8618774414062, 1553.9862670898438, 1078.534652709961, 1599.1165771484375, 1068.7105407714844]
# 1/1 [==============================] - 0s 138ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25768      0.3244     0.41792]
# Done. (193.0ms) Inference, (0.5ms) NMS
# video 1/27 (74/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1505.2697143554688, 1098.0431365966797, 0.3535102903842926, 1510.0731506347656, 1082.7409286499023, 0.37344539165496826, 1509.0921325683594, 1080.0037994384766, 0.012497094459831715, 1553.9892883300781, 1075.3193817138672, 0.7323383092880249, 1606.3409729003906, 1054.2554626464844, 0.033092767000198364, 1600.0701904296875, 1174.9364471435547, 0.7316519021987915, 1622.7136535644531, 1115.9554138183594, 0.5853025317192078, 1470.8979034423828, 1241.986083984375, 0.811200737953186, 1490.3610534667969, 1212.9115905761719, 0.4802597165107727, 1321.6466751098633, 1218.2314147949219, 0.8565347194671631, 1332.1976318359375, 1219.6443786621094, 0.6769886016845703, 1615.3577880859375, 1373.3920593261719, 0.6155377626419067, 1615.8041687011719, 1343.3036499023438, 0.5346442461013794, 1503.1031951904297, 1483.1124877929688, 0.7187088131904602, 1495.5740966796875, 1469.9482727050781, 0.5867260098457336, 1398.3734283447266, 1676.0771484375, 0.38383883237838745, 1387.6832580566406, 1665.158935546875, 0.30526915192604065]
# Skeleton data for frame: [[     1505.3        1098      1510.1      1082.7      1509.1        1080        1554      1075.3      1606.3      1054.3      1600.1      1174.9      1622.7        1116      1470.9        1242      1490.4      1212.9      1321.6      1218.2      1332.2      1219.6      1615.4      1373.4      1615.8      1343.3
#        1503.1      1483.1      1495.6      1469.9      1398.4      1676.1      1387.7      1665.2]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1505.2697143554688, 1098.0431365966797, 1510.0731506347656, 1082.7409286499023, 1509.0921325683594, 1080.0037994384766, 1553.9892883300781, 1075.3193817138672, 1606.3409729003906, 1054.2554626464844]
# 1/1 [==============================] - 0s 136ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25769     0.32442     0.41788]
# Done. (202.5ms) Inference, (0.5ms) NMS
# video 1/27 (75/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1503.6681060791016, 1096.1808471679688, 0.5070444345474243, 1512.4208984375, 1083.6371612548828, 0.5222323536872864, 1505.6447296142578, 1079.9092178344727, 0.027246754616498947, 1562.5805358886719, 1077.7031631469727, 0.6894010901451111, 1546.6100158691406, 1064.5253219604492, 0.10878648608922958, 1613.1556091308594, 1129.29443359375, 0.5223174691200256, 1567.6396179199219, 1115.037109375, 0.8263021111488342, 1460.958999633789, 1232.786376953125, 0.3283214867115021, 1455.4273681640625, 1229.3826904296875, 0.7498260140419006, 1324.702003479004, 1223.548828125, 0.40181854367256165, 1316.9608688354492, 1216.5219116210938, 0.7499590516090393, 1629.4242248535156, 1351.1466064453125, 0.6427779197692871, 1596.9348754882812, 1336.1344299316406, 0.7925519943237305, 1509.4043579101562, 1487.341552734375, 0.6625590324401855, 1495.1551361083984, 1476.6929931640625, 0.7592313885688782, 1406.9141387939453, 1694.5545043945312, 0.4108983278274536, 1393.8453521728516, 1694.5472412109375, 0.4875456988811493]
# Skeleton data for frame: [[     1503.7      1096.2      1512.4      1083.6      1505.6      1079.9      1562.6      1077.7      1546.6      1064.5      1613.2      1129.3      1567.6        1115        1461      1232.8      1455.4      1229.4      1324.7      1223.5        1317      1216.5      1629.4      1351.1      1596.9      1336.1
#        1509.4      1487.3      1495.2      1476.7      1406.9      1694.6      1393.8      1694.5]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1503.6681060791016, 1096.1808471679688, 1512.4208984375, 1083.6371612548828, 1505.6447296142578, 1079.9092178344727, 1562.5805358886719, 1077.7031631469727, 1546.6100158691406, 1064.5253219604492]
# 1/1 [==============================] - 0s 137ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [     0.2577     0.32442     0.41788]
# Done. (204.3ms) Inference, (0.5ms) NMS
# ...
# Skeleton data for frame: [[       1319      860.55      1314.1      837.45      1324.3      835.56      1197.9      816.54      1299.9      824.38      1133.3      960.93      1318.7      981.08      1187.1      1147.7      1326.8      1199.9      1347.2      1159.1      1339.2      1376.1      1110.1      1348.9      1241.9      1357.3
#        1120.1      1647.5      1291.7      1640.9      1099.5      1949.3      1327.9      1939.2]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1319.0281982421875, 860.5516510009766, 1314.072998046875, 837.4530487060547, 1324.3198547363281, 835.5578918457031, 1197.8819732666016, 816.5390319824219, 1299.9323120117188, 824.3761291503906]
# 1/1 [==============================] - 0s 134ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246      0.4176]
# Done. (192.2ms) Inference, (0.5ms) NMS
# video 1/27 (177/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1332.7722473144531, 855.2753448486328, 0.07046633958816528, 1325.8175048828125, 833.8671264648438, 0.004455011337995529, 1337.1997375488281, 832.3383636474609, 0.09320858865976334, 1208.6170196533203, 824.1134185791016, 0.28139618039131165, 1311.8786010742188, 830.5096435546875, 0.7994800209999084, 1149.1077270507812, 976.8342895507812, 0.8208876252174377, 1335.6118469238281, 986.7599487304688, 0.9601237773895264, 1144.3882446289062, 1196.1365356445312, 0.37039217352867126, 1339.1759033203125, 1207.1910400390625, 0.9122170209884644, 1222.6569519042969, 1359.5366821289062, 0.22490188479423523, 1345.6797180175781, 1380.5517578125, 0.7670694589614868, 1120.3009643554688, 1357.3276977539062, 0.9509497284889221, 1254.4925231933594, 1364.6858520507812, 0.9775635600090027, 1122.5948028564453, 1650.4166870117188, 0.9552763104438782, 1301.6553039550781, 1643.1212768554688, 0.9790757894515991, 1102.4988555908203, 1954.4974365234375, 0.9003217816352844, 1328.5939636230469, 1937.6171875, 0.936150848865509]
# Skeleton data for frame: [[     1332.8      855.28      1325.8      833.87      1337.2      832.34      1208.6      824.11      1311.9      830.51      1149.1      976.83      1335.6      986.76      1144.4      1196.1      1339.2      1207.2      1222.7      1359.5      1345.7      1380.6      1120.3      1357.3      1254.5      1364.7
#        1122.6      1650.4      1301.7      1643.1      1102.5      1954.5      1328.6      1937.6]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1332.7722473144531, 855.2753448486328, 1325.8175048828125, 833.8671264648438, 1337.1997375488281, 832.3383636474609, 1208.6170196533203, 824.1134185791016, 1311.8786010742188, 830.5096435546875]
# 1/1 [==============================] - 0s 135ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246     0.41761]
# Done. (193.4ms) Inference, (0.5ms) NMS
# video 1/27 (178/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1348.4971313476562, 853.7751770019531, 0.10190944373607635, 1336.8778076171875, 827.24462890625, 0.010929438285529613, 1351.2226257324219, 831.415771484375, 0.060229964554309845, 1235.1346130371094, 828.2225036621094, 0.5526783466339111, 1329.7256469726562, 831.3390655517578, 0.8893728256225586, 1155.736099243164, 978.6556701660156, 0.9026902318000793, 1347.9180908203125, 986.5120239257812, 0.9816350936889648, 1155.500747680664, 1191.8416748046875, 0.2923612594604492, 1351.7261047363281, 1197.8302307128906, 0.9308003187179565, 1241.2278747558594, 1338.7568969726562, 0.1395578533411026, 1347.8897705078125, 1372.4526977539062, 0.7107560634613037, 1125.652328491211, 1367.8529052734375, 0.9697986245155334, 1269.8195495605469, 1378.1194458007812, 0.9880591034889221, 1109.8700714111328, 1653.0319213867188, 0.9731734395027161, 1308.09619140625, 1648.3609619140625, 0.9901339411735535, 1102.6049346923828, 1944.220703125, 0.9557521343231201, 1321.6570739746094, 1940.285888671875, 0.9773284196853638]
# Skeleton data for frame: [[     1348.5      853.78      1336.9      827.24      1351.2      831.42      1235.1      828.22      1329.7      831.34      1155.7      978.66      1347.9      986.51      1155.5      1191.8      1351.7      1197.8      1241.2      1338.8      1347.9      1372.5      1125.7      1367.9      1269.8      1378.1
#        1109.9        1653      1308.1      1648.4      1102.6      1944.2      1321.7      1940.3]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1348.4971313476562, 853.7751770019531, 1336.8778076171875, 827.24462890625, 1351.2226257324219, 831.415771484375, 1235.1346130371094, 828.2225036621094, 1329.7256469726562, 831.3390655517578]
# 1/1 [==============================] - 0s 135ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246     0.41761]
# Done. (189.9ms) Inference, (0.5ms) NMS
# video 1/27 (179/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1363.219482421875, 854.4247894287109, 0.09177073836326599, 1351.656005859375, 828.1751708984375, 0.009662976488471031, 1366.7866821289062, 832.1585845947266, 0.060443177819252014, 1247.4412841796875, 828.7492370605469, 0.532200038433075, 1338.9305725097656, 833.3165893554688, 0.8930894732475281, 1161.7054748535156, 970.2986145019531, 0.9061887264251709, 1361.4984741210938, 985.2169799804688, 0.9819421172142029, 1162.679214477539, 1183.6230773925781, 0.31235814094543457, 1363.532470703125, 1195.6632995605469, 0.9338836669921875, 1243.265380859375, 1335.9954833984375, 0.15251688659191132, 1347.9854431152344, 1369.7323608398438, 0.7258065342903137, 1131.3026580810547, 1360.0936889648438, 0.9716066718101501, 1278.9702453613281, 1373.0018310546875, 0.9886223673820496, 1112.1141815185547, 1642.6142578125, 0.9750939011573792, 1315.1126098632812, 1645.8115234375, 0.9907386302947998, 1105.0122833251953, 1935.5797119140625, 0.9585530161857605, 1322.9309997558594, 1944.3441162109375, 0.9784082174301147]
# Skeleton data for frame: [[     1363.2      854.42      1351.7      828.18      1366.8      832.16      1247.4      828.75      1338.9      833.32      1161.7       970.3      1361.5      985.22      1162.7      1183.6      1363.5      1195.7      1243.3        1336        1348      1369.7      1131.3      1360.1        1279        1373
#        1112.1      1642.6      1315.1      1645.8        1105      1935.6      1322.9      1944.3]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1363.219482421875, 854.4247894287109, 1351.656005859375, 828.1751708984375, 1366.7866821289062, 832.1585845947266, 1247.4412841796875, 828.7492370605469, 1338.9305725097656, 833.3165893554688]
# 1/1 [==============================] - 0s 134ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246     0.41761]
# Done. (189.8ms) Inference, (0.5ms) NMS
# video 1/27 (180/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1370.7727966308594, 849.3024749755859, 0.049781784415245056, 1362.3330078125, 829.0965881347656, 0.005315991118550301, 1374.5846252441406, 827.4514923095703, 0.0724310353398323, 1251.4913635253906, 816.6893463134766, 0.27013513445854187, 1356.6845397949219, 828.4891815185547, 0.7838823199272156, 1179.5534057617188, 967.9391479492188, 0.8127744793891907, 1380.3717651367188, 988.1668395996094, 0.9533427953720093, 1168.5626831054688, 1179.29638671875, 0.37245872616767883, 1371.9752807617188, 1208.9827270507812, 0.8880937695503235, 1223.3374786376953, 1345.9859619140625, 0.23239561915397644, 1348.3499145507812, 1374.5559692382812, 0.7219575643539429, 1146.2073822021484, 1339.4915161132812, 0.9450438618659973, 1286.2995300292969, 1351.5089721679688, 0.9734945297241211, 1142.9662322998047, 1623.6795043945312, 0.9548519253730774, 1315.2384033203125, 1623.1795654296875, 0.9775057435035706, 1114.883773803711, 1938.8201904296875, 0.9025661945343018, 1333.040283203125, 1937.2979736328125, 0.9344272017478943]
# Skeleton data for frame: [[     1370.8       849.3      1362.3       829.1      1374.6      827.45      1251.5      816.69      1356.7      828.49      1179.6      967.94      1380.4      988.17      1168.6      1179.3        1372        1209      1223.3        1346      1348.3      1374.6      1146.2      1339.5      1286.3      1351.5
#          1143      1623.7      1315.2      1623.2      1114.9      1938.8        1333      1937.3]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1370.7727966308594, 849.3024749755859, 1362.3330078125, 829.0965881347656, 1374.5846252441406, 827.4514923095703, 1251.4913635253906, 816.6893463134766, 1356.6845397949219, 828.4891815185547]
# 1/1 [==============================] - 0s 134ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246     0.41761]
# Done. (191.9ms) Inference, (0.5ms) NMS
# video 1/27 (181/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1350.5618896484375, 843.8074493408203, 0.006909375544637442, 1340.8067016601562, 824.6212921142578, 0.003335752757266164, 1361.3707580566406, 823.8347320556641, 0.00652675237506628, 1256.0025329589844, 808.8628692626953, 0.6578280925750732, 1375.91064453125, 824.8050537109375, 0.7171809077262878, 1177.7300567626953, 964.4666137695312, 0.814064621925354, 1391.1158447265625, 986.9528503417969, 0.9486697912216187, 1165.6040496826172, 1174.5061645507812, 0.3878461420536041, 1381.400390625, 1212.7645874023438, 0.8738951086997986, 1223.8433837890625, 1339.0394897460938, 0.22783853113651276, 1353.7135620117188, 1369.05224609375, 0.6819251179695129, 1150.0643310546875, 1337.83984375, 0.9477946162223816, 1297.3978271484375, 1350.6256103515625, 0.9735881686210632, 1142.7474822998047, 1613.096923828125, 0.9569242000579834, 1319.0606994628906, 1616.7794799804688, 0.9774236083030701, 1120.9460754394531, 1924.587646484375, 0.9073740839958191, 1329.3372192382812, 1928.6024169921875, 0.9359946846961975]
# Skeleton data for frame: [[     1350.6      843.81      1340.8      824.62      1361.4      823.83        1256      808.86      1375.9      824.81      1177.7      964.47      1391.1      986.95      1165.6      1174.5      1381.4      1212.8      1223.8        1339      1353.7      1369.1      1150.1      1337.8      1297.4      1350.6
#        1142.7      1613.1      1319.1      1616.8      1120.9      1924.6      1329.3      1928.6]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1350.5618896484375, 843.8074493408203, 1340.8067016601562, 824.6212921142578, 1361.3707580566406, 823.8347320556641, 1256.0025329589844, 808.8628692626953, 1375.91064453125, 824.8050537109375]
# 1/1 [==============================] - 0s 135ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246     0.41761]
# Done. (195.1ms) Inference, (0.5ms) NMS
# video 1/27 (182/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1382.6527709960938, 849.3490447998047, 0.04903077706694603, 1370.6873779296875, 823.8178405761719, 0.006236416287720203, 1388.1490783691406, 828.0557403564453, 0.027079004794359207, 1271.3178405761719, 821.4861907958984, 0.6178550124168396, 1376.7346801757812, 826.3209075927734, 0.8161831498146057, 1191.438003540039, 967.5430297851562, 0.9176966547966003, 1393.6004028320312, 984.79833984375, 0.9828080534934998, 1182.8709564208984, 1183.833984375, 0.33852067589759827, 1391.3919067382812, 1203.5961303710938, 0.9320402145385742, 1238.3924865722656, 1346.4208374023438, 0.1400412917137146, 1361.7615051269531, 1363.6043701171875, 0.689338207244873, 1166.4826354980469, 1346.7244262695312, 0.9752699732780457, 1308.8141479492188, 1359.7111206054688, 0.9897612929344177, 1156.919937133789, 1626.5115966796875, 0.9780263304710388, 1327.784912109375, 1632.7001953125, 0.9915173053741455, 1127.2205429077148, 1917.17724609375, 0.962775707244873, 1328.3254089355469, 1933.5703125, 0.9803778529167175]
# Skeleton data for frame: [[     1382.7      849.35      1370.7      823.82      1388.1      828.06      1271.3      821.49      1376.7      826.32      1191.4      967.54      1393.6       984.8      1182.9      1183.8      1391.4      1203.6      1238.4      1346.4      1361.8      1363.6      1166.5      1346.7      1308.8      1359.7
#        1156.9      1626.5      1327.8      1632.7      1127.2      1917.2      1328.3      1933.6]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1382.6527709960938, 849.3490447998047, 1370.6873779296875, 823.8178405761719, 1388.1490783691406, 828.0557403564453, 1271.3178405761719, 821.4861907958984, 1376.7346801757812, 826.3209075927734]
# 1/1 [==============================] - 0s 135ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246     0.41761]
# Done. (195.6ms) Inference, (0.4ms) NMS
# video 1/27 (183/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV: Keypoints for frame: [1368.0196838378906, 849.1706695556641, 0.011179126799106598, 1359.1326599121094, 829.0514373779297, 0.003601417411118746, 1376.6277160644531, 828.5608978271484, 0.012147731147706509, 1266.6638641357422, 813.7510070800781, 0.595899760723114, 1381.541748046875, 832.6749267578125, 0.6851295828819275, 1186.8884735107422, 968.5920715332031, 0.9537630081176758, 1403.4219360351562, 988.3254089355469, 0.9614513516426086, 1145.5938262939453, 1185.8943481445312, 0.8989928960800171, 1396.3880615234375, 1208.4751586914062, 0.9167935848236084, 1121.3694686889648, 1355.6557006835938, 0.8157126903533936, 1365.9095458984375, 1367.0284423828125, 0.8346326947212219, 1163.9606475830078, 1348.7724609375, 0.9851008057594299, 1309.55859375, 1358.9541625976562, 0.9862092137336731, 1156.2188110351562, 1628.8560791015625, 0.9771158695220947, 1330.7158203125, 1638.694580078125, 0.978854775428772, 1137.5923690795898, 1909.6043701171875, 0.9210891723632812, 1334.5367126464844, 1933.3134765625, 0.9239216446876526]
# Skeleton data for frame: [[       1368      849.17      1359.1      829.05      1376.6      828.56      1266.7      813.75      1381.5      832.67      1186.9      968.59      1403.4      988.33      1145.6      1185.9      1396.4      1208.5      1121.4      1355.7      1365.9        1367        1164      1348.8      1309.6        1359
#        1156.2      1628.9      1330.7      1638.7      1137.6      1909.6      1334.5      1933.3]]
# Length of skeleton_data: 34
# First few values of skeleton_data: [1368.0196838378906, 849.1706695556641, 1359.1326599121094, 829.0514373779297, 1376.6277160644531, 828.5608978271484, 1266.6638641357422, 813.7510070800781, 1381.541748046875, 832.6749267578125]
# 1/1 [==============================] - 0s 134ms/step
# Skeleton data shape: (1, 632, 34)
# Skeleton data type: float32
# Prediction probabilities: [    0.25779      0.3246     0.41761]
# Done. (191.5ms) Inference, (0.5ms) NMS
# video 1/27 (184/482) /Users/jihoon/venvs/skeleton-rnn/input_data/경은_LB_H1.MOV:
